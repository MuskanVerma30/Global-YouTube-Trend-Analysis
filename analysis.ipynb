# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Global YouTube Statistics.csv', encoding='latin1')

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series  245000000.0  2.280000e+11
# 1     2              YouTube Movies  170000000.0  0.000000e+00
# 2     3                     MrBeast  166000000.0  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes  162000000.0  1.640000e+11
# 4     5                   SET India  159000000.0  1.480000e+11
#
#            category                       Title  uploads Country of origin  \
# 0             Music                    T-Series    20082             India
# 1  Film & Animation               youtubemovies        1     United States
# 2     Entertainment                     MrBeast      741     United States
# 3         Education  Cocomelon - Nursery Rhymes      966     United States
# 4             Shows                   SET India   116536             India
#
#          Country Abbreviation  ... subscribers_for_last_30_days  created_year  \
# 0          india           IN  ...                    2000000.0        2006.0
# 1  United States           US  ...                          NaN        2006.0
# 2  United States           US  ...                    8000000.0        2012.0
# 3  United States           US  ...                    1000000.0        2006.0
# 4          India           IN  ...                    1000000.0        2006.0
#
#    created_month  created_date  Gross tertiary education enrollment (%)  \
# 0            Mar          13.0                                     28.1
# 1            NaN           5.0                                     88.2
# 2            Feb          20.0                                     88.2
# 3            Sep           1.0                                     88.2
# 4            Sep          20.0                                     28.1
#
#      Population  Unemployment rate  Urban_population   Latitude  Longitude
# 0  1.366418e+09               5.36       471031528.0  20.593684  78.962880
# 1  3.282395e+08              14.70       270663028.0  37.090240 -95.712891
# 2  3.282395e+08              14.70       270663028.0  37.090240 -95.712891
# 3  3.282395e+08              14.70       270663028.0  37.090240 -95.712891
# 4  1.366418e+09               5.36       471031528.0  20.593684  78.962880
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (1006, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 29 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     1006 non-null   int64
#  1   Youtuber                                 1006 non-null   object
#  2   subscribers                              1003 non-null   float64
#  3   video views                              1006 non-null   float64
#  4   category                                 951 non-null    object
#  5   Title                                    1006 non-null   object
#  6   uploads                                  1006 non-null   int64
#  7   Country of origin                        881 non-null    object
#  8   Country                                  881 non-null    object
#  9   Abbreviation                             881 non-null    object
#  10  channel_type                             974 non-null    object
#  11  video_views_rank                         1005 non-null   float64
#  12  country_rank                             887 non-null    float64
#  13  channel_type_rank                        971 non-null    float64
#  14  video_views_for_the_last_30_days         949 non-null    float64
#  15  lowest_monthly_earnings                  1006 non-null   float64
#  16  highest_monthly_earnings                 1006 non-null   float64
#  17  lowest_yearly_earnings                   1006 non-null   float64
#  18  highest_yearly_earnings                  1006 non-null   float64
#  19  subscribers_for_last_30_days             666 non-null    float64
#  20  created_year                             1001 non-null   float64
#  21  created_month                            994 non-null    object
#  22  created_date                             1001 non-null   float64
#  23  Gross tertiary education enrollment (%)  880 non-null    float64
#  24  Population                               880 non-null    float64
#  25  Unemployment rate                        880 non-null    float64
#  26  Urban_population                         880 non-null    float64
#  27  Latitude                                 880 non-null    float64
#  28  Longitude                                880 non-null    float64
# dtypes: float64(19), int64(2), object(8)
# memory usage: 228.1+ KB

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  3
# video views                                  0
# category                                    55
# Title                                        0
# uploads                                      0
# Country of origin                          125
# Country                                    125
# Abbreviation                               125
# channel_type                                32
# video_views_rank                             1
# country_rank                               119
# channel_type_rank                           35
# video_views_for_the_last_30_days            57
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               340
# created_year                                 5
# created_month                               12
# created_date                                 5
# Gross tertiary education enrollment (%)    126
# Population                                 126
# Unemployment rate                          126
# Urban_population                           126
# Latitude                                   126
# Longitude                                  126
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(11)

# %%
duplicates = df[df.duplicated()]
print(duplicates)
# Out:
#       rank                                           Youtuber  subscribers  \
# 995     12                                                WWE   96000000.0
# 996     13                                             Gaming   93600000.0
# 997     39  LooLoo Kids - Nursery Rhymes and Children's Songs   54000000.0
# 998     40                                         Ed Sheeran   53500000.0
# 999     41                                  Infobells - Hindi   53300000.0
# 1000   620                                          MY FAMILY   15700000.0
# 1001   779                                           The Dodo   14200000.0
# 1002   787                                   Supercar Blondie   14100000.0
# 1003   871                               Just For Laughs Gags   13300000.0
# 1004   872                                   Kabita's Kitchen   13300000.0
# 1005   873                                         BanderitaX   13300000.0
#
#        video views          category  \
# 995   7.742847e+10            Sports
# 996   0.000000e+00               NaN
# 997   3.231243e+10             Music
# 998   3.036768e+10             Music
# 999   3.051617e+10         Education
# 1000  6.153496e+09               NaN
# 1001  9.964117e+09    Pets & Animals
# 1002  5.405563e+09  Autos & Vehicles
# 1003  7.406629e+09            Comedy
# 1004  2.831276e+09     Howto & Style
# 1005  4.129249e+09            Gaming
#
#                                                 Title  uploads  \
# 995                                               WWE    70127
# 996                                            Gaming        0
# 997   LooLoo Kids - Nursery Rhymes and Children's ï¿½       11
# 998                                        Ed Sheeran      383
# 999                                 Infobells - Hindi      577
# 1000                                        My Family      150
# 1001                                Dorukhan Gï¿½ï¿½ï        8
# 1002                                 Supercar Blondie      855
# 1003                             Just For Laughs Gags     6916
# 1004                                 Kabita's Kitchen     1489
# 1005                                       BanderitaX     1640
#
#          Country of origin               Country Abbreviation  ...  \
# 995          United States         United States           US  ...
# 996                    NaN                   NaN          NaN  ...
# 997                    NaN                   NaN          NaN  ...
# 998         United Kingdom        United Kingdom           GB  ...
# 999                  India                 India           IN  ...
# 1000             Singapore             Singapore           SG  ...
# 1001                   NaN                   NaN          NaN  ...
# 1002  United Arab Emirates  United Arab Emirates           AE  ...
# 1003         United States         United States           US  ...
# 1004                 India                 India           IN  ...
# 1005          Saudi Arabia          Saudi Arabia           SA  ...
#
#      subscribers_for_last_30_days  created_year  created_month  created_date  \
# 995                      600000.0        2007.0            May          11.0
# 996                           NaN        2013.0            Dec          15.0
# 997                           NaN        2016.0            Nov          29.0
# 998                      100000.0        2006.0            Aug           8.0
# 999                     1600000.0        2014.0            Jun           6.0
# 1000                        800.0        2019.0            Dec           3.0
# 1001                          5.0        2006.0            Jun          14.0
# 1002                     500000.0        2007.0            Sep          12.0
# 1003                     100000.0        2007.0            Jan          14.0
# 1004                          NaN        2014.0            Oct           7.0
# 1005                     200000.0        2013.0            Aug          20.0
#
#       Gross tertiary education enrollment (%)    Population  \
# 995                                      88.2  3.282395e+08
# 996                                       NaN           NaN
# 997                                       NaN           NaN
# 998                                      60.0  6.683440e+07
# 999                                      28.1  1.366418e+09
# 1000                                     84.8  5.703569e+06
# 1001                                      NaN           NaN
# 1002                                     36.8  9.770529e+06
# 1003                                     88.2  3.282395e+08
# 1004                                     28.1  1.366418e+09
# 1005                                     68.0  3.426853e+07
#
#       Unemployment rate  Urban_population   Latitude   Longitude
# 995               14.70       270663028.0  37.090240  -95.712891
# 996                 NaN               NaN        NaN         NaN
# 997                 NaN               NaN        NaN         NaN
# 998                3.85        55908316.0  55.378051   -3.435973
# 999                5.36       471031528.0  20.593684   78.962880
# 1000               4.11         5703569.0   1.352083  103.819836
# 1001                NaN               NaN        NaN         NaN
# 1002               2.35         8479744.0  23.424076   53.847818
# 1003              14.70       270663028.0  37.090240  -95.712891
# 1004               5.36       471031528.0  20.593684   78.962880
# 1005               5.93        28807838.0  23.885942   45.079162
#
# [11 rows x 29 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Country'] = df['Country'].str.strip().str.title()
df['Country of origin'] = df['Country of origin'].str.strip().str.title()

# %%
is_identical = df['Country'].equals(df['Country of origin'])
print(f"Are the columns identical? {is_identical}")
# Out:
# Are the columns identical? True

# %%
#drop country of origin column
df = df.drop(columns=['Country of origin'])

# %%
df['subscribers_for_last_30_days'] = pd.to_numeric(df['subscribers_for_last_30_days'], errors='coerce')

# %%
df['subscribers_for_last_30_days'].isnull().sum()
# Out:
# np.int64(337)

# %%
df['subscribers_for_last_30_days'].fillna(0, inplace = True)
# Out:
# /tmp/ipykernel_1607/3758679453.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['subscribers_for_last_30_days'].fillna(0, inplace = True)

# %%
df['subscribers_for_last_30_days'].head()
# Out:
# 0    2000000.0
# 1          0.0
# 2    8000000.0
# 3    1000000.0
# 4    1000000.0
# Name: subscribers_for_last_30_days, dtype: float64

# %%
df['subscribers_for_last_30_days'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['video_views_for_the_last_30_days'].fillna(0, inplace = True)
df['video_views_for_the_last_30_days'].isnull().sum()
# Out:
# /tmp/ipykernel_1607/4257352757.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['video_views_for_the_last_30_days'].fillna(0, inplace = True)
# np.int64(0)

# %%
#top 10 YouTube channels based on the number of subscribers
top_10_channels = df.nlargest(10, 'subscribers')
print(top_10_channels[['Youtuber', 'subscribers']])
# Out:
#                      Youtuber  subscribers
# 0                    T-Series  245000000.0
# 1              YouTube Movies  170000000.0
# 2                     MrBeast  166000000.0
# 3  Cocomelon - Nursery Rhymes  162000000.0
# 4                   SET India  159000000.0
# 5                       Music  119000000.0
# 6         ýýý Kids Diana Show  112000000.0
# 7                   PewDiePie  111000000.0
# 8                 Like Nastya  106000000.0
# 9               Vlad and Niki   98900000.0

# %%
#top 10 countries by number of youtube channels
top_10_countries = df['Country'].value_counts().head(10)
print(top_10_countries)
# Out:
# Country
# United States     313
# India             168
# Brazil             62
# United Kingdom     43
# Mexico             33
# Indonesia          28
# Spain              22
# Thailand           18
# South Korea        17
# Russia             16
# Name: count, dtype: int64

# %% [markdown]
# Visualizations

# %%
#top 10 countries by number of channels
plt.figure(figsize=(10,6))
sns.barplot(top_10_countries)
plt.title('Top 10 Countries by Number of Channels')
plt.xlabel('Country')
plt.ylabel('Number of Channels')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(
    x='Youtuber',
    y='subscribers',
    data=top_10_channels
)
plt.title('Top 10 YouTube Channels by Subcribers')
plt.xlabel('Youtuber')
plt.ylabel('Subscribers')
plt.xticks(rotation=90)
plt.show()

# %%
#scatter plot for top 5 categories with their subscribers and video viewers
top_5_categories = df['category'].value_counts().head(5).index
filtered_df = df[df['category'].isin(top_5_categories)]
plt.figure(figsize=(10,6))
sns.scatterplot(data= filtered_df, x='subscribers_for_last_30_days', y='video_views_for_the_last_30_days', hue='category')
plt.title('Scatter Plot of Subscribers and Video Views by Category')
plt.xlabel('Subscribers')
plt.ylabel('Video Views')
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)

plt.figure(figsize=(14,10))

sns.heatmap(
    numeric_df.corr(),
    cmap='coolwarm',
    annot=False
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    x=df['subscribers'],
    y=df['video views'],

)

plt.title("Subscribers vs Video Views")

plt.show()

# %%
#channel type vs. video views
plt.figure(figsize=(10,6))
channel_view = df.groupby('channel_type')['video views'].mean().sort_values(ascending=False)
sns.barplot(x=channel_view.index, y=channel_view.values)
plt.xlabel('Channel Type')
plt.ylabel('Average Video Views')
plt.xticks(rotation=90)
plt.title("Channel Type vs. Video Views")
# Out:
# Text(0.5, 1.0, 'Channel Type vs. Video Views')

# %%
plt.figure(figsize=(10,6))
channel_view = df.groupby('channel_type')['video_views_for_the_last_30_days'].sum().sort_values(ascending=False)
sns.barplot(x=channel_view.index, y=channel_view.values)
plt.xlabel('Channel Type')
plt.ylabel('Average Video Views in last 30 days')
plt.xticks(rotation=90)
plt.title("Channel Type vs. Video Views")
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    x='uploads',
    y='subscribers',
    data=df
)

plt.title("Uploads vs Subscribers")

plt.show()

# %%
plt.figure(figsize=(10,6))
channel_view = df.groupby('channel_type')['video_views_for_the_last_30_days'].sum().sort_values(ascending=False)
plt.barh(y=channel_view.index, width=channel_view.values)
plt.xlabel('Video Views in last 30 days (Sum)')
plt.ylabel('Channel Type')
plt.title("Recent Video Views by Channel Type")
plt.show()

# %%
bins = [0,2009,2014,2019, df['created_year'].max()]
labels = [
    'Before 2010',
    '2010-2014',
    '2015-2019',
    'After 2019'
]
df['creation_period'] = pd.cut(df['created_year'], bins=bins, labels=labels)

# %%
plt.figure(figsize=(10,6))
creation_period_counts = df['creation_period'].value_counts()
plt.pie(creation_period_counts, labels = creation_period_counts.index, autopct='%1.1f%%')
plt.title('Creation Period Distribution')
plt.show()
